# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# !pip install patool
# Out:
# Requirement already satisfied: patool in /usr/local/lib/python3.10/dist-packages (2.2.0)

# %%
import patoolib

# %%
patoolib.extract_archive('/content/drive/MyDrive/upGrad/CNN_assignment.zip')
# Out:
# INFO patool: Extracting /content/drive/MyDrive/upGrad/CNN_assignment.zip ...
# INFO:patool:Extracting /content/drive/MyDrive/upGrad/CNN_assignment.zip ...
# INFO patool: running /usr/bin/7z x -o./Unpack_nl_c3tmf -- /content/drive/MyDrive/upGrad/CNN_assignment.zip
# INFO:patool:running /usr/bin/7z x -o./Unpack_nl_c3tmf -- /content/drive/MyDrive/upGrad/CNN_assignment.zip
# INFO patool:     with input=''
# INFO:patool:    with input=''
# INFO patool: ... /content/drive/MyDrive/upGrad/CNN_assignment.zip extracted to `CNN_assignment' (local file exists).
# INFO:patool:... /content/drive/MyDrive/upGrad/CNN_assignment.zip extracted to `CNN_assignment' (local file exists).
# 'CNN_assignment'

# %%
# Defining the path for train and test images
## Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/Skin cancer ISIC The International Skin Imaging Collaboration/Train")
data_dir_test = pathlib.Path('/content/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  print(len(images))
  print(len(labels))
  plt.imshow(images[10].numpy().astype("uint8"))
  plt.title(class_names[labels[10]])
  plt.axis("off")
# Out:
# 32
# 32

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model

# %%
### Your code goes here
num_classes = 9

#A Sequential model is appropriate for a plain stack of layers where each layer has exactly one input tensor and one output tensor
model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),

  #2D convolution layer (e.g. spatial convolution over images).
  layers.Conv2D(16, 3, padding='same', activation='relu'),

  #We slide over the feature map and extract tiles of a specified size.
  #Downsamples the input along its spatial dimensions (height and width) by taking the maximum value over an input window (of size defined by pool_size) for each channel of the input.
  layers.MaxPooling2D(),

  #We slide over the feature map and extract tiles of a specified size.
  layers.Conv2D(32, 3, padding='same', activation='relu'),

  layers.MaxPooling2D(),

  layers.Conv2D(64, 3, padding='same', activation='relu'),

  #We slide over the feature map and extract tiles of a specified size.
  #Advantages of downsampling - Decreased size of input for upcoming layers, Works against overfitting
  layers.MaxPooling2D(),

  #Flattening - Convert into 1D feature vector.  Flattens all its structure to create a single long feature vector
  ##Flattens the input. Does not affect the batch size.
  layers.Flatten(),

  #fully connected layer
  #A hidden layer in which each node is connected to every node in the subsequent hidden layer.
  #A fully connected layer is also known as a dense layer.

  layers.Dense(128, activation='relu'),

  #Dense is the only actual network layer in that model. A Dense layer feeds all outputs from the previous layer to all its neurons, each neuron providing one output to the next layer.
  #It's the most basic layer in neural networks. A Dense(10) has ten neurons. A Dense(512) has 512 neurons.
  #Dense implements the operation: output = activation(dot(input, kernel)
  #Dense Layer - A dense layer represents a matrix vector multiplication.  each input node is connected to each output node.
  layers.Dense(num_classes)
  #Dense Layer - A dense layer represents a matrix vector multiplication.  each input node is connected to each output node.
])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_3 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_9 (Conv2D)           (None, 180, 180, 16)      448
#
#  max_pooling2d_9 (MaxPoolin  (None, 90, 90, 16)        0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 90, 90, 32)        4640
#
#  max_pooling2d_10 (MaxPooli  (None, 45, 45, 32)        0
#  ng2D)
#
#  conv2d_11 (Conv2D)          (None, 45, 45, 64)        18496
#
#  max_pooling2d_11 (MaxPooli  (None, 22, 22, 64)        0
#  ng2D)
#
#  flatten_3 (Flatten)         (None, 30976)             0
#
#  dense_6 (Dense)             (None, 128)               3965056
#
#  dense_7 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3989801 (15.22 MB)
# Trainable params: 3989801 (15.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 169/169 [==============================] - 29s 46ms/step - loss: 1.9358 - accuracy: 0.2871 - val_loss: 1.5345 - val_accuracy: 0.4417
# Epoch 2/20
# 169/169 [==============================] - 4s 21ms/step - loss: 1.4234 - accuracy: 0.4635 - val_loss: 1.3282 - val_accuracy: 0.5145
# Epoch 3/20
# 169/169 [==============================] - 3s 20ms/step - loss: 1.2493 - accuracy: 0.5362 - val_loss: 1.1487 - val_accuracy: 0.5768
# Epoch 4/20
# 169/169 [==============================] - 3s 20ms/step - loss: 1.0678 - accuracy: 0.6061 - val_loss: 1.2159 - val_accuracy: 0.5479
# Epoch 5/20
# 169/169 [==============================] - 3s 20ms/step - loss: 0.9342 - accuracy: 0.6569 - val_loss: 1.0408 - val_accuracy: 0.6199
# Epoch 6/20
# 169/169 [==============================] - 4s 22ms/step - loss: 0.7621 - accuracy: 0.7268 - val_loss: 0.8912 - val_accuracy: 0.6719
# Epoch 7/20
# 169/169 [==============================] - 4s 21ms/step - loss: 0.6556 - accuracy: 0.7693 - val_loss: 0.8199 - val_accuracy: 0.7179
# Epoch 8/20
# 169/169 [==============================] - 4s 22ms/step - loss: 0.5370 - accuracy: 0.8077 - val_loss: 0.8731 - val_accuracy: 0.6986
# Epoch 9/20
# 169/169 [==============================] - 4s 21ms/step - loss: 0.4173 - accuracy: 0.8540 - val_loss: 0.8337 - val_accuracy: 0.7305
# Epoch 10/20
# 169/169 [==============================] - 3s 20ms/step - loss: 0.3519 - accuracy: 0.8769 - val_loss: 0.8729 - val_accuracy: 0.7268
# Epoch 11/20
# 169/169 [==============================] - 3s 20ms/step - loss: 0.3029 - accuracy: 0.8978 - val_loss: 0.7881 - val_accuracy: 0.7699
# Epoch 12/20
# 169/169 [==============================] - 3s 20ms/step - loss: 0.3129 - accuracy: 0.8941 - val_loss: 0.7762 - val_accuracy: 0.7721
# Epoch 13/20
# 169/169 [==============================] - 3s 20ms/step - loss: 0.2299 - accuracy: 0.9197 - val_loss: 0.8002 - val_accuracy: 0.7803
# Epoch 14/20
# 169/169 [==============================] - 3s 20ms/step - loss: 0.2026 - accuracy: 0.9280 - val_loss: 0.8362 - val_accuracy: 0.7513
# Epoch 15/20
# 169/169 [==============================] - 3s 21ms/step - loss: 0.1780 - accuracy: 0.9303 - val_loss: 0.8615 - val_accuracy: 0.7906
# Epoch 16/20
# 169/169 [==============================] - 3s 20ms/step - loss: 0.1559 - accuracy: 0.9432 - val_loss: 0.7499 - val_accuracy: 0.8099
# Epoch 17/20
# 169/169 [==============================] - 3s 20ms/step - loss: 0.1444 - accuracy: 0.9455 - val_loss: 0.8160 - val_accuracy: 0.7832
# Epoch 18/20
# 169/169 [==============================] - 4s 23ms/step - loss: 0.1389 - accuracy: 0.9494 - val_loss: 0.7843 - val_accuracy: 0.8085
# Epoch 19/20
# 169/169 [==============================] - 3s 20ms/step - loss: 0.2212 - accuracy: 0.9164 - val_loss: 1.0524 - val_accuracy: 0.7268
# Epoch 20/20
# 169/169 [==============================] - 3s 20ms/step - loss: 0.1891 - accuracy: 0.9279 - val_loss: 0.8464 - val_accuracy: 0.7854

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# > ### The model is overfitting. Training accuracy is high whereas validation accuracy is very low.

# %%
#Choose an appropriate data augumentation strategy.

data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal",
                                                 input_shape=(img_height,
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
    layers.experimental.preprocessing.RandomTranslation(1,.5,fill_mode="reflect",interpolation="bilinear",seed=None,fill_value=0.0),
    layers.experimental.preprocessing.RandomCrop(img_height,img_width),
  ]
)

# %%
# visualize how your augmentation strategy works for one instance of training image.
# Your code goes here
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(256, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Compiling the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 169/169 [==============================] - 23s 127ms/step - loss: 2.2370 - accuracy: 0.1593 - val_loss: 1.9424 - val_accuracy: 0.2242
# Epoch 2/20
# 169/169 [==============================] - 19s 111ms/step - loss: 1.8876 - accuracy: 0.2591 - val_loss: 1.8644 - val_accuracy: 0.2821
# Epoch 3/20
# 169/169 [==============================] - 19s 113ms/step - loss: 1.6909 - accuracy: 0.3310 - val_loss: 1.6223 - val_accuracy: 0.3875
# Epoch 4/20
# 169/169 [==============================] - 19s 110ms/step - loss: 1.6089 - accuracy: 0.3674 - val_loss: 1.7557 - val_accuracy: 0.3215
# Epoch 5/20
# 169/169 [==============================] - 18s 109ms/step - loss: 1.5839 - accuracy: 0.3809 - val_loss: 1.7235 - val_accuracy: 0.3556
# Epoch 6/20
# 169/169 [==============================] - 18s 108ms/step - loss: 1.5569 - accuracy: 0.3882 - val_loss: 1.6344 - val_accuracy: 0.4083
# Epoch 7/20
# 169/169 [==============================] - 18s 108ms/step - loss: 1.4813 - accuracy: 0.4251 - val_loss: 1.5289 - val_accuracy: 0.4187
# Epoch 8/20
# 169/169 [==============================] - 18s 108ms/step - loss: 1.4695 - accuracy: 0.4340 - val_loss: 1.4498 - val_accuracy: 0.4432
# Epoch 9/20
# 169/169 [==============================] - 19s 110ms/step - loss: 1.4366 - accuracy: 0.4492 - val_loss: 1.4094 - val_accuracy: 0.4469
# Epoch 10/20
# 169/169 [==============================] - 18s 109ms/step - loss: 1.4022 - accuracy: 0.4572 - val_loss: 1.4419 - val_accuracy: 0.4246
# Epoch 11/20
# 169/169 [==============================] - 18s 107ms/step - loss: 1.4084 - accuracy: 0.4635 - val_loss: 1.4338 - val_accuracy: 0.4439
# Epoch 12/20
# 169/169 [==============================] - 18s 108ms/step - loss: 1.3963 - accuracy: 0.4529 - val_loss: 1.3834 - val_accuracy: 0.4722
# Epoch 13/20
# 169/169 [==============================] - 18s 108ms/step - loss: 1.3539 - accuracy: 0.4746 - val_loss: 1.3536 - val_accuracy: 0.4729
# Epoch 14/20
# 169/169 [==============================] - 18s 108ms/step - loss: 1.3495 - accuracy: 0.4800 - val_loss: 1.3260 - val_accuracy: 0.4729
# Epoch 15/20
# 169/169 [==============================] - 18s 108ms/step - loss: 1.3789 - accuracy: 0.4655 - val_loss: 1.3372 - val_accuracy: 0.4722
# Epoch 16/20
#  39/169 [=====>........................] - ETA: 13s - loss: 1.3463 - accuracy: 0.4943
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-86-ac17ea520f87> in <cell line: 3>()
#       1 ## Your code goes here, note: train your model for 20 epochs
#       2 epochs = 20
# ----> 3 history = model.fit(
#       4   train_ds,
#       5   validation_data=val_ds,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1811                             logs = tmp_logs
#    1812                             end_step = step + data_handler.step_increment
# -> 1813                             callbacks.on_train_batch_end(end_step, logs)
#    1814                             if self.stop_training:
#    1815                                 break
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in on_train_batch_end(self, batch, logs)
#     473         """
#     474         if self._should_call_train_batch_hooks:
# --> 475             self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#     476
#     477     def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     320             self._call_batch_begin_hook(mode, batch, logs)
#     321         elif hook == "end":
# --> 322             self._call_batch_end_hook(mode, batch, logs)
#     323         else:
#     324             raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     343             self._batch_times.append(batch_time)
#     344
# --> 345         self._call_batch_hook_helper(hook_name, batch, logs)
#     346
#     347         if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     391         for callback in self.callbacks:
#     392             hook = getattr(callback, hook_name)
# --> 393             hook(batch, logs)
#     394
#     395         if self._check_timing:
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in on_train_batch_end(self, batch, logs)
#    1091
#    1092     def on_train_batch_end(self, batch, logs=None):
# -> 1093         self._batch_update_progbar(batch, logs)
#    1094
#    1095     def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.10/dist-packages/keras/src/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1167         if self.verbose == 1:
#    1168             # Only block async when verbose = 1.
# -> 1169             logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1170             self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1171
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     692         return t.item() if np.ndim(t) == 0 else t
#     693
# --> 694     return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     695
#     696
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     629     ValueError: If wrong keyword arguments are provided.
#     630   """
# --> 631   return nest_util.map_structure(
#     632       nest_util.Modality.CORE, func, *structure, **kwargs
#     633   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in map_structure(modality, func, *structure, **kwargs)
#    1064   """
#    1065   if modality == Modality.CORE:
# -> 1066     return _tf_core_map_structure(func, *structure, **kwargs)
#    1067   elif modality == Modality.DATA:
#    1068     return _tf_data_map_structure(func, *structure, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in _tf_core_map_structure(func, *structure, **kwargs)
#    1104   return _tf_core_pack_sequence_as(
#    1105       structure[0],
# -> 1106       [func(*x) for x in entries],
#    1107       expand_composites=expand_composites,
#    1108   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/nest_util.py in <listcomp>(.0)
#    1104   return _tf_core_pack_sequence_as(
#    1105       structure[0],
# -> 1106       [func(*x) for x in entries],
#    1107       expand_composites=expand_composites,
#    1108   )
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     685         # Don't turn ragged or sparse tensors to NumPy.
#     686         if isinstance(t, tf.Tensor):
# --> 687             t = t.numpy()
#     688         # Strings, ragged and sparse tensors don't have .item(). Return them
#     689         # as-is.
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#     392     """
#     393     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# --> 394     maybe_arr = self._numpy()  # pylint: disable=protected-access
#     395     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#     396
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#     358   def _numpy(self):
#     359     try:
# --> 360       return self._numpy_internal()
#     361     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#     362       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.
from glob import glob
path_list = [x for x in glob(os.path.join(data_dir_train, '*', '*.jpg'))]
lesion_list = [os.path.basename(os.path.dirname(y)) for y in glob(os.path.join(data_dir_train, '*', '*.jpg'))]
len(path_list)
# Out:
# 2239

# %%
dataframe_dict_original = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict_original.items()),columns = ['Path','Label'])
original_df
# Out:
#                                                    Path           Label
# 0     /content/Skin cancer ISIC The International Sk...        melanoma
# 1     /content/Skin cancer ISIC The International Sk...        melanoma
# 2     /content/Skin cancer ISIC The International Sk...        melanoma
# 3     /content/Skin cancer ISIC The International Sk...        melanoma
# 4     /content/Skin cancer ISIC The International Sk...        melanoma
# ...                                                 ...             ...
# 2234  /content/Skin cancer ISIC The International Sk...  dermatofibroma
# 2235  /content/Skin cancer ISIC The International Sk...  dermatofibroma
# 2236  /content/Skin cancer ISIC The International Sk...  dermatofibroma
# 2237  /content/Skin cancer ISIC The International Sk...  dermatofibroma
# 2238  /content/Skin cancer ISIC The International Sk...  dermatofibroma
#
# [2239 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder
from collections import Counter
# split into input and output elements
X, y = original_df['Path'], original_df['Label']
# label encode the target variable
y = LabelEncoder().fit_transform(y)
# summarize distribution
counter = Counter(y)
for k,v in counter.items():
	per = v / len(y) * 100
	print('Class=%d, n=%d (%.3f%%)' % (k, v, per))
# plot the distribution
plt.bar(counter.keys(), counter.values())
plt.show()
# Out:
# Class=3, n=438 (19.562%)
# Class=4, n=357 (15.945%)
# Class=7, n=181 (8.084%)
# Class=1, n=376 (16.793%)
# Class=6, n=77 (3.439%)
# Class=0, n=114 (5.092%)
# Class=8, n=139 (6.208%)
# Class=5, n=462 (20.634%)
# Class=2, n=95 (4.243%)

# %% [markdown]
# ####  Write your findings here:
# #### - Which class has the least number of samples?
# ## Class 6 has the least number of samles
#
# #### - Which classes dominate the data in terms proportionate number of samples?
# ## Class 5 dominates the data

# %% [markdown]
# ####  Rectify the class imbalance
# #### Use `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
#
jpg',
#  '/content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000258.jpg_915d815b-60dd-4f9f-a17b-33ea427eb621.jpg',
#  '/content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0025957.jpg_e5be8886-0bf7-40f4-938e-29881653b459.jpg',
#  '/content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000337.jpg_d4094e8e-5d99-476d-8cbb-a6cbd8e3e9ee.jpg',
#  '/content/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output/nevus_original_ISIC_0000504.jpg_94722ced-8ef3-467e-9211-cc6b5b250938.jpg',
#  ...]

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new
# Out:
# ['melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'melanoma',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  'nevus',
#  ...]

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df._append(df2)

# %%
new_df['Label'].value_counts()
# Out:
# Label
# pigmented benign keratosis    962
# melanoma                      938
# basal cell carcinoma          876
# nevus                         857
# squamous cell carcinoma       681
# vascular lesion               639
# actinic keratosis             614
# dermatofibroma                595
# seborrheic keratosis          577
# Name: count, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### Create a training dataset

# %%
print(data_dir_train)
# Out:
# /content/Skin cancer ISIC The International Skin Imaging Collaboration/Train

# %%
data_dir_train = data_dir_train +
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# ####  Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### Create your model (make sure to include normalization)

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# #### Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ####  Train your model

# %%
epochs = 50
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/50
# 169/169 [==============================] - 31s 63ms/step - loss: 1.7927 - accuracy: 0.3186 - val_loss: 1.4751 - val_accuracy: 0.4566
# Epoch 2/50
# 169/169 [==============================] - 4s 26ms/step - loss: 1.3871 - accuracy: 0.4748 - val_loss: 1.2764 - val_accuracy: 0.5271
# Epoch 3/50
# 169/169 [==============================] - 4s 26ms/step - loss: 1.2091 - accuracy: 0.5551 - val_loss: 1.1349 - val_accuracy: 0.5642
# Epoch 4/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.9992 - accuracy: 0.6409 - val_loss: 1.0223 - val_accuracy: 0.6140
# Epoch 5/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.8639 - accuracy: 0.6910 - val_loss: 1.1874 - val_accuracy: 0.5850
# Epoch 6/50
# 169/169 [==============================] - 5s 27ms/step - loss: 0.7357 - accuracy: 0.7341 - val_loss: 0.8576 - val_accuracy: 0.6830
# Epoch 7/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.6175 - accuracy: 0.7864 - val_loss: 0.7760 - val_accuracy: 0.7327
# Epoch 8/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.5008 - accuracy: 0.8283 - val_loss: 0.9255 - val_accuracy: 0.6904
# Epoch 9/50
# 169/169 [==============================] - 5s 27ms/step - loss: 0.4205 - accuracy: 0.8527 - val_loss: 0.8229 - val_accuracy: 0.7365
# Epoch 10/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.3374 - accuracy: 0.8809 - val_loss: 0.7398 - val_accuracy: 0.7684
# Epoch 11/50
# 169/169 [==============================] - 5s 29ms/step - loss: 0.3183 - accuracy: 0.8839 - val_loss: 0.7119 - val_accuracy: 0.7595
# Epoch 12/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.2675 - accuracy: 0.9052 - val_loss: 0.7482 - val_accuracy: 0.7988
# Epoch 13/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.2297 - accuracy: 0.9175 - val_loss: 0.6875 - val_accuracy: 0.7944
# Epoch 14/50
# 169/169 [==============================] - 5s 27ms/step - loss: 0.1876 - accuracy: 0.9301 - val_loss: 0.7409 - val_accuracy: 0.7899
# Epoch 15/50
# 169/169 [==============================] - 5s 28ms/step - loss: 0.1846 - accuracy: 0.9342 - val_loss: 0.7132 - val_accuracy: 0.7914
# Epoch 16/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.1738 - accuracy: 0.9368 - val_loss: 0.8540 - val_accuracy: 0.7476
# Epoch 17/50
# 169/169 [==============================] - 5s 27ms/step - loss: 0.1722 - accuracy: 0.9375 - val_loss: 0.7876 - val_accuracy: 0.8211
# Epoch 18/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.1702 - accuracy: 0.9362 - val_loss: 0.8516 - val_accuracy: 0.7899
# Epoch 19/50
# 169/169 [==============================] - 5s 28ms/step - loss: 0.1764 - accuracy: 0.9347 - val_loss: 0.8905 - val_accuracy: 0.7973
# Epoch 20/50
# 169/169 [==============================] - 4s 27ms/step - loss: 0.1628 - accuracy: 0.9355 - val_loss: 0.7998 - val_accuracy: 0.8218
# Epoch 21/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.1217 - accuracy: 0.9533 - val_loss: 0.8116 - val_accuracy: 0.8144
# Epoch 22/50
# 169/169 [==============================] - 5s 29ms/step - loss: 0.1144 - accuracy: 0.9533 - val_loss: 0.7818 - val_accuracy: 0.8203
# Epoch 23/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.1413 - accuracy: 0.9471 - val_loss: 0.8060 - val_accuracy: 0.8218
# Epoch 24/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.1739 - accuracy: 0.9349 - val_loss: 0.8951 - val_accuracy: 0.7929
# Epoch 25/50
# 169/169 [==============================] - 5s 27ms/step - loss: 0.1232 - accuracy: 0.9531 - val_loss: 0.8065 - val_accuracy: 0.8129
# Epoch 26/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.1234 - accuracy: 0.9494 - val_loss: 0.8969 - val_accuracy: 0.8018
# Epoch 27/50
# 169/169 [==============================] - 5s 28ms/step - loss: 0.0940 - accuracy: 0.9573 - val_loss: 0.8309 - val_accuracy: 0.8337
# Epoch 28/50
# 169/169 [==============================] - 5s 27ms/step - loss: 0.1346 - accuracy: 0.9455 - val_loss: 0.9224 - val_accuracy: 0.7936
# Epoch 29/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.1641 - accuracy: 0.9414 - val_loss: 0.9789 - val_accuracy: 0.7817
# Epoch 30/50
# 169/169 [==============================] - 5s 27ms/step - loss: 0.1401 - accuracy: 0.9466 - val_loss: 0.8229 - val_accuracy: 0.8144
# Epoch 31/50
# 169/169 [==============================] - 4s 27ms/step - loss: 0.0961 - accuracy: 0.9599 - val_loss: 1.0210 - val_accuracy: 0.7906
# Epoch 32/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.0906 - accuracy: 0.9620 - val_loss: 0.8524 - val_accuracy: 0.8003
# Epoch 33/50
# 169/169 [==============================] - 5s 27ms/step - loss: 0.0905 - accuracy: 0.9599 - val_loss: 0.9127 - val_accuracy: 0.8085
# Epoch 34/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.0930 - accuracy: 0.9596 - val_loss: 0.9370 - val_accuracy: 0.8189
# Epoch 35/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.0891 - accuracy: 0.9625 - val_loss: 0.9242 - val_accuracy: 0.8033
# Epoch 36/50
# 169/169 [==============================] - 5s 27ms/step - loss: 0.1023 - accuracy: 0.9575 - val_loss: 0.9179 - val_accuracy: 0.8137
# Epoch 37/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.1768 - accuracy: 0.9399 - val_loss: 1.1437 - val_accuracy: 0.7587
# Epoch 38/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.1569 - accuracy: 0.9432 - val_loss: 1.0030 - val_accuracy: 0.7914
# Epoch 39/50
# 169/169 [==============================] - 5s 27ms/step - loss: 0.1036 - accuracy: 0.9583 - val_loss: 1.0070 - val_accuracy: 0.8070
# Epoch 40/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.0996 - accuracy: 0.9573 - val_loss: 0.9412 - val_accuracy: 0.8151
# Epoch 41/50
# 169/169 [==============================] - 5s 28ms/step - loss: 0.0882 - accuracy: 0.9616 - val_loss: 0.9984 - val_accuracy: 0.7951
# Epoch 42/50
# 169/169 [==============================] - 5s 27ms/step - loss: 0.0956 - accuracy: 0.9562 - val_loss: 0.9612 - val_accuracy: 0.8107
# Epoch 43/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.0945 - accuracy: 0.9594 - val_loss: 1.0496 - val_accuracy: 0.8033
# Epoch 44/50
# 169/169 [==============================] - 5s 28ms/step - loss: 0.0882 - accuracy: 0.9590 - val_loss: 0.9785 - val_accuracy: 0.8196
# Epoch 45/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.0953 - accuracy: 0.9573 - val_loss: 1.1766 - val_accuracy: 0.8003
# Epoch 46/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.1017 - accuracy: 0.9598 - val_loss: 1.0848 - val_accuracy: 0.8025
# Epoch 47/50
# 169/169 [==============================] - 5s 27ms/step - loss: 0.0905 - accuracy: 0.9605 - val_loss: 1.2664 - val_accuracy: 0.7973
# Epoch 48/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.1252 - accuracy: 0.9486 - val_loss: 1.2310 - val_accuracy: 0.7988
# Epoch 49/50
# 169/169 [==============================] - 4s 26ms/step - loss: 0.0966 - accuracy: 0.9609 - val_loss: 1.0256 - val_accuracy: 0.7951
# Epoch 50/50
# 169/169 [==============================] - 5s 27ms/step - loss: 0.0962 - accuracy: 0.9598 - val_loss: 0.9866 - val_accuracy: 0.7877

# %% [markdown]
# ####  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ####  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# ### After 50 epochs, we find that the training accuracy is 96% and validation accuracy is 88%.  Got rid of underfitting, there is slight overfitting. Class rebalance has reduced the loss.
